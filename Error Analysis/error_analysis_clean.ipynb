# %%
import re
import pandas as pd
from typing import Dict

# %% [markdown]
# # Pipeline

# %%
LANG_CONFIG = {
    "ar": {
        "text_col": "Question",
        "regex": {
            "medical_keywords": re.compile(
                r"(الم|نزيف|افرازات|حمل|عملية|طفل|اختبار|دواء|جرعة|حمية|ارتفاع ضغط|سكري|حرارة|كسر|التهاب)",
                re.IGNORECASE
            ),
            "rare_procedures": re.compile(
                r"(ربط عنق الرحم|ICSI|CRP|قسطرة|استئصال|منظار|تصوير بالموجات فوق الصوتية|عملية قيصرية|تحليل TSH|علاج دوائي)",
                re.IGNORECASE
            ),
            "numbers_and_labs": re.compile(
                r"(\d{1,3}(\.\d+)?\s*(ملغ|مل|سم|مم|نبض|bpm|CRP|Hb|هرمون)?)"
            ),
            "negation_or_reassurance": re.compile(
                r"(لا تقلقي|طبيعي|لا يوجد مشكلة|آمن|لا خطورة)", re.IGNORECASE
            ),
            "sensitive_topics": re.compile(
                r"(الجماع|القذف|الدورة الشهرية|الحمل|الرضاعة|الخصوبة|المني|الفرج|الثدي)", re.IGNORECASE
            ),
            "polite_phrases": re.compile(
                r"(السلام عليكم|مرحبا|شكرا|من فضلك|جزاك الله خيرا)", re.IGNORECASE
            ),
            "narrative_style": re.compile(
                r"(أشعر|أعاني|لاحظت|منذ|خلال|اليوم|فجأة|بعد أن|في الوقت الحالي|كنت|صرت|بدأت)", re.IGNORECASE
            ),
        }
    },

    "en": {
        "text_col": "Question_eng",
        "regex": {
            "medical_keywords": re.compile(
                r"\b(pain|swelling|cyst|discharge|infection|CRP|testosterone|surgery|fever|treatment|ulcer|cough|shortness of breath)\b",
                re.IGNORECASE
            ),
            "rare_procedures": re.compile(
                r"\b(ICSI|cervical cerclage|CBK test|echocardiogram|catheterization|angioplasty|laparoscopy|endoscopy)\b",
                re.IGNORECASE
            ),
            "numbers_and_labs": re.compile(
                r"\b(\d{1,3}(\.\d+)?\s*(mg|ml|g|cm|mmHg|bpm|CRP|Hb|testosterone)?)\b",
                re.IGNORECASE
            ),
            "negation_or_reassurance": re.compile(
                r"\b(don't worry|it's normal|no problem|minor|safe|harmless|not serious)\b",
                re.IGNORECASE
            ),
            "sensitive_topics": re.compile(
                r"\b(sexual|ejaculation|menstrual|pregnancy|reproductive|contraceptive|intercourse|masturbation|breast|fertility)\b",
                re.IGNORECASE
            ),
            "polite_phrases": re.compile(
                r"\b(peace be upon you|hello|hi|thank you|please)\b",
                re.IGNORECASE
            ),
            "narrative_style": re.compile(
                r"\b(I (feel|have|suffer|noticed)|Recently|For the last|Since|Today|Yesterday)\b",
                re.IGNORECASE
            ),
        }
    }
}

# %%
def analyze_df(df: pd.DataFrame, lang: str) -> pd.DataFrame:
    cfg = LANG_CONFIG[lang]
    text_col = cfg["text_col"]
    regex = cfg["regex"]

    rows = []
    for text in df[text_col].fillna("").astype(str):
        row = {}
        for k, p in regex.items():
            matches = p.findall(text)
            row[f"{k}_present"] = int(bool(matches))
            row[f"{k}_count"] = len(matches)
        rows.append(row)

    return pd.DataFrame(rows)

# %%
from typing import Literal

def analysis_pipeline(
    df: pd.DataFrame,
    lang: str,
    mode: Literal["present", "count"] = "count"
):
    """
    Unified analysis pipeline for medical text datasets.

    Parameters
    ----------
    df : pd.DataFrame
        Input dataframe. Must contain a 'Trigger' column (0/1).
        May optionally contain a 'prediction' column (0/1).
    lang : str
        Language code ('ar' or 'en'), used to select text column
        and language-specific regex patterns.
    mode : {'present', 'count'}, default='present'
        - 'present': use binary keyword presence per row (recommended for statistics)
        - 'count'  : use total keyword occurrences (useful for qualitative analysis)

    Returns
    -------
    dict
        Dictionary containing aggregated keyword statistics for:
        - TRIGGER / NON_TRIGGER
        - FP / FN (if prediction column exists)
        - Length diagnostics (if prediction column exists)
    """

    assert "Trigger" in df.columns, "Trigger column is required"
    assert mode in {"present", "count"}, "mode must be 'present' or 'count'"

    out = {}
    suffix = "_present" if mode == "present" else "_count"

    # ---------- Trigger vs Non-trigger ----------
    trigger_df = df[df["Trigger"] == 1]
    non_trigger_df = df[df["Trigger"] == 0]

    out["TRIGGER"] = analyze_df(trigger_df, lang).filter(like=suffix).sum()
    out["NON_TRIGGER"] = analyze_df(non_trigger_df, lang).filter(like=suffix).sum()

    # ---------- FP / FN (only if prediction exists) ----------
    if "prediction" in df.columns:
        fp_df = df[(df["prediction"] == 1) & (df["Trigger"] == 0)]
        fn_df = df[(df["prediction"] == 0) & (df["Trigger"] == 1)]

        out["FP"] = analyze_df(fp_df, lang).filter(like=suffix).sum()
        out["FN"] = analyze_df(fn_df, lang).filter(like=suffix).sum()

        # ---------- Length diagnostics ----------
        text_col = LANG_CONFIG[lang]["text_col"]

        out["FP_avg_len_chars"] = fp_df[text_col].str.len().mean()
        out["FN_avg_len_chars"] = fn_df[text_col].str.len().mean()

        out["FP_avg_len_words"] = fp_df[text_col].str.split().str.len().mean()
        out["FN_avg_len_words"] = fn_df[text_col].str.split().str.len().mean()

    return out

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency, fisher_exact

def significance_from_pipeline(df: pd.DataFrame, results_dict: dict = None, lang: str = None, alpha: float = 0.05):
    """
    Compute statistical significance of features between two groups:
    - Full dataset: Trigger vs Non-Trigger
    - Result dataset: FP vs FN

    Automatically detects totals, selects test, computes odds ratio, and shows which group is enriched.

    Parameters
    ----------
    df : pd.DataFrame
        Original dataset containing 'Trigger' and optionally 'prediction' columns.
    results_dict : dict, optional
        Output from analysis_pipeline. If None, will auto-generate TRIGGER/NON_TRIGGER or FP/FN.
    lang : str, optional
        Language key for analysis_pipeline (needed if results_dict is None)
    alpha : float
        Significance threshold.

    Returns
    -------
    pd.DataFrame
        Keyword-level table with:
        - counts per group
        - p-value
        - test used
        - significant
        - odds ratio
        - enriched_in: which group is enriched
    """

    # Determine group type and compute results_dict if not provided
    if results_dict is None:
        assert lang is not None, "Must provide 'lang' if results_dict is not given."
        from copy import deepcopy
        from __main__ import analysis_pipeline  # assumes analysis_pipeline is imported

        # Full dataset (no prediction column)
        if "prediction" not in df.columns:
            results_dict = analysis_pipeline(df, lang=lang, mode="present")
            # Should contain "TRIGGER" and "NON_TRIGGER"
            keys = ["TRIGGER", "NON_TRIGGER"]
        # Result dataset (with prediction)
        else:
            results_dict = analysis_pipeline(df, lang=lang, mode="present")
            keys = ["FP", "FN"]
    else:
        keys = list(results_dict.keys())
        if len(keys) != 2:
            raise ValueError("results_dict must have exactly two keys.")

    group1, group2 = keys

    # Compute totals from DataFrame if possible
    if "prediction" in df.columns and set(keys) == {"FP", "FN"}:
        total1 = len(df[(df["prediction"] == 1) & (df["Trigger"] == 0)])  # FP
        total2 = len(df[(df["prediction"] == 0) & (df["Trigger"] == 1)])  # FN
    else:
        total1 = (df["Trigger"] == 1).sum()  # TRIGGER
        total2 = (df["Trigger"] == 0).sum()  # NON_TRIGGER

    counts1 = results_dict[group1]
    counts2 = results_dict[group2]

    results = []

    for kw in counts1.index:
        a = counts1[kw]
        c = counts2[kw]
        b = total1 - a
        d = total2 - c

        table = np.array([[a, b], [c, d]])

        # Select test
        if (table < 5).any():
            odds_ratio, p_value = fisher_exact(table)
            test = "Fisher Exact"
        else:
            chi2, p_value, dof, expected = chi2_contingency(table)
            odds_ratio = (a * d) / (b * c) if b > 0 and c > 0 else np.nan
            test = "Chi-square"

        # Determine enrichment
        if odds_ratio > 1:
            enriched_in = group1
        elif odds_ratio < 1:
            enriched_in = group2
        else:
            enriched_in = "None"
            
        significant =  p_value < alpha
        if not significant:
            enriched_in = "Z"

        results.append({
            "Keyword": kw.replace("_present", ""),
            f"{group1}_with": a,
            f"{group2}_with": c,
            "p_value": p_value,
            "Significant": significant,
            "Test": test,
            "Odds_Ratio": odds_ratio,
            "Enriched_in": enriched_in
        })

    return pd.DataFrame(results).sort_values("p_value")

# %% [markdown]
# # Test here

# %% [markdown]
# ## Show for Full Dataset

# %%
df_memo = pd.read_csv("../Eval/Memo_Dataset.csv")
test_lang = "ar"

# Run your pipeline
results_ara_memo_full = analysis_pipeline(df_memo, lang=test_lang, mode="present")

# Compute significance
sig_df = significance_from_pipeline(df=df_memo, results_dict=results_ara_memo_full, lang=test_lang)

sig_df
# Out:
#                    Keyword  TRIGGER_with  NON_TRIGGER_with        p_value  \
# 3  negation_or_reassurance           415              1042  6.768711e-134
# 2         numbers_and_labs          2490              2365   1.415647e-37
# 4         sensitive_topics           472               595   8.629937e-23
# 0         medical_keywords          4148              2651   1.490572e-09
# 6          narrative_style          1766              1184   8.973565e-02
# 5           polite_phrases          1221               911   2.199133e-01
# 1          rare_procedures            90                59   6.947113e-01
#
#    Significant        Test  Odds_Ratio  Enriched_in
# 3         True  Chi-square    0.241691  NON_TRIGGER
# 2         True  Chi-square    0.625999  NON_TRIGGER
# 4         True  Chi-square    0.534349  NON_TRIGGER
# 0         True  Chi-square    1.239728      TRIGGER
# 6        False  Chi-square    1.075904            Z
# 5        False  Chi-square    0.941889            Z
# 1        False  Chi-square    1.083479            Z

# %% [markdown]
# ## Test on ALL models

# %%
import os
import pandas as pd

# Assuming analysis_pipeline and significance_from_pipeline are already defined

def run_directory_analysis(dir_path, mode="present", save_txt=True, txt_path="model_analysis_summary.txt"):
    """
    Reads all CSVs in a directory, runs analysis and significance pipeline for both languages,
    prints clear tables with model names and language, and summarizes significant features.
    Optionally saves the full output to a text file.
    """
    all_sig_features = {}  # to summarize later
    lines_to_save = []

    languages = ["ar", "en"]

    for file in os.listdir(dir_path):
        if not file.endswith(".csv"):
            continue

        # Determine model name (strip timestamp)
        base_name = file.split("_202")[0]

        # Read CSV
        df = pd.read_csv(os.path.join(dir_path, file))

        for lang in languages:
            sep_line = "="*80
            header = f"MODEL / CSV: {base_name} | on col LANGUAGE: {lang}"
            lines_to_save.append(sep_line)
            lines_to_save.append(header)
            lines_to_save.append("-"*80)

            print(sep_line)
            print(header)
            print("-"*80)

            # Run analysis pipeline
            results = analysis_pipeline(df, lang=lang, mode=mode)

            # Keep only FP / FN if predictions exist
            if "FP" in results and "FN" in results:
                results_filtered = {k: v for k, v in results.items() if k in ['FP', 'FN']}
                print("FP / FN Counts:")
                print(pd.DataFrame(results_filtered))
                lines_to_save.append("FP / FN Counts:")
                lines_to_save.append(pd.DataFrame(results_filtered).to_string())
            else:
                # Full dataset (Trigger vs Non-Trigger)
                results_filtered = {k: v for k, v in results.items() if k in ['TRIGGER', 'NON_TRIGGER']}
                print("TRIGGER / NON_TRIGGER Counts:")
                print(pd.DataFrame(results_filtered))
                lines_to_save.append("TRIGGER / NON_TRIGGER Counts:")
                lines_to_save.append(pd.DataFrame(results_filtered).to_string())

            # Compute significance
            sig_df = significance_from_pipeline(df=df, results_dict=results_filtered, lang=lang)
            print("-"*80)
            print("Significance Table:")
            print(sig_df)
            lines_to_save.append("-"*80)
            lines_to_save.append("Significance Table:")
            lines_to_save.append(sig_df.to_string(index=False))
            lines_to_save.append(sep_line + "\n")
            print(sep_line + "\n\n")

            # Record which features are significant for this model+lang
            sig_features = sig_df[sig_df["Significant"]]["Keyword"].tolist()
            all_sig_features[f"{base_name}_{lang}"] = sig_features

    # Summary table at the end
    print("SUMMARY OF SIGNIFICANT FEATURES PER MODEL / LANGUAGE:")
    summary_df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in all_sig_features.items()]))
    print(summary_df)
    lines_to_save.append("SUMMARY OF SIGNIFICANT FEATURES PER MODEL / LANGUAGE:")
    lines_to_save.append(summary_df.to_string())

    # Save to txt if requested
    if save_txt:
        with open(txt_path, "w", encoding="utf-8") as f:
            for line in lines_to_save:
                f.write(str(line) + "\n")

    return all_sig_features

# %%
dir_path = "results/"
all_sig = run_directory_analysis(dir_path, mode="present")
# Out:
# ================================================================================
# MODEL / CSV: Claude-Haiku-4.5_Arabic | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         282  208
# rare_procedures_present           11    3
# numbers_and_labs_present         214  126
# negation_or_reassurance_present   87   24
# sensitive_topics_present          49   40
# polite_phrases_present            83   59
# narrative_style_present          136   80
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance       87       24  0.000002         True
# 2         numbers_and_labs      214      126  0.005989         True
# 6          narrative_style      136       80  0.049033         True
# 1          rare_procedures       11        3  0.111305        False
# 0         medical_keywords      282      208  0.733211        False
# 5           polite_phrases       83       59  0.759127        False
# 4         sensitive_topics       49       40  0.793147        False
#
#            Test  Odds_Ratio Enriched_in
# 3    Chi-square    3.088269          FP
# 2    Chi-square    1.480667          FP
# 6    Chi-square    1.386154          FP
# 1  Fisher Exact    2.812298           Z
# 0    Chi-square    1.055722           Z
# 5    Chi-square    1.076520           Z
# 4    Chi-square    0.919392           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: Claude-Haiku-4.5_Arabic | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         188  122
# rare_procedures_present            1    2
# numbers_and_labs_present         205  121
# negation_or_reassurance_present    3    3
# sensitive_topics_present          90   60
# polite_phrases_present           110   72
# narrative_style_present          245  156
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 2         numbers_and_labs      205      121  0.008527         True
# 6          narrative_style      245      156  0.029638         True
# 0         medical_keywords      188      122  0.120731        False
# 5           polite_phrases      110       72  0.324841        False
# 4         sensitive_topics       90       60  0.458981        False
# 1          rare_procedures        1        2  0.580681        False
# 3  negation_or_reassurance        3        3  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 2    Chi-square    1.461986          FP
# 6    Chi-square    1.352541          FP
# 0    Chi-square    1.258318           Z
# 5    Chi-square    1.197249           Z
# 4    Chi-square    1.162844           Z
# 1  Fisher Exact    0.377143           Z
# 3  Fisher Exact    0.755258           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: Claude-Haiku-4.5_English | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         269  207
# rare_procedures_present            7    4
# numbers_and_labs_present         207  121
# negation_or_reassurance_present   80   23
# sensitive_topics_present          40   40
# polite_phrases_present            79   62
# narrative_style_present          127   82
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance       80       23  0.000006         True
# 2         numbers_and_labs      207      121  0.002277         True
# 6          narrative_style      127       82  0.158153        False
# 4         sensitive_topics       40       40  0.285826        False
# 1          rare_procedures        7        4  0.764056        False
# 0         medical_keywords      269      207  0.933920        False
# 5           polite_phrases       79       62  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 3    Chi-square    3.018259          FP
# 2    Chi-square    1.553175          FP
# 6    Chi-square    1.270484           Z
# 4    Chi-square    0.757962           Z
# 1  Fisher Exact    1.364583           Z
# 0    Chi-square    1.020282           Z
# 5    Chi-square    0.988090           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: Claude-Haiku-4.5_English | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         192  135
# rare_procedures_present            1    2
# numbers_and_labs_present         197  115
# negation_or_reassurance_present    3    3
# sensitive_topics_present          77   58
# polite_phrases_present           103   76
# narrative_style_present          249  165
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 2         numbers_and_labs      197      115  0.003217         True
# 6          narrative_style      249      165  0.037203         True
# 0         medical_keywords      192      135  0.297682        False
# 1          rare_procedures        1        2  0.584011        False
# 5           polite_phrases      103       76  0.766841        False
# 4         sensitive_topics       77       58  0.921308        False
# 3  negation_or_reassurance        3        3  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 2    Chi-square    1.538466          FP
# 6    Chi-square    1.336294          FP
# 0    Chi-square    1.168095           Z
# 1  Fisher Exact    0.387255           Z
# 5    Chi-square    1.066273           Z
# 4    Chi-square    1.036986           Z
# 3  Fisher Exact    0.775591           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: GPT-4o-mini_Arabic | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         378  120
# rare_procedures_present           12    1
# numbers_and_labs_present         296   68
# negation_or_reassurance_present  123   13
# sensitive_topics_present          73   31
# polite_phrases_present           123   39
# narrative_style_present          177   42
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance      123       13  0.000007         True
# 2         numbers_and_labs      296       68  0.000195         True
# 6          narrative_style      177       42  0.017901         True
# 1          rare_procedures       12        1  0.202635        False
# 0         medical_keywords      378      120  0.322615        False
# 4         sensitive_topics       73       31  0.348927        False
# 5           polite_phrases      123       39  0.710546        False
#
#            Test  Odds_Ratio Enriched_in
# 3    Chi-square    3.708543          FP
# 2    Chi-square    1.837680          FP
# 6    Chi-square    1.591029          FP
# 1  Fisher Exact    4.169492           Z
# 0    Chi-square    1.169737           Z
# 4    Chi-square    0.786159           Z
# 5    Chi-square    1.098827           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: GPT-4o-mini_Arabic | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         233  65
# rare_procedures_present            2   1
# numbers_and_labs_present         285  64
# negation_or_reassurance_present    4   3
# sensitive_topics_present         125  40
# polite_phrases_present           158  42
# narrative_style_present          339  71
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with       p_value  Significant  \
# 6          narrative_style      339       71  7.132124e-07         True
# 2         numbers_and_labs      285       64  1.543721e-04         True
# 0         medical_keywords      233       65  8.994788e-02        False
# 5           polite_phrases      158       42  1.180223e-01        False
# 3  negation_or_reassurance        4        3  3.803508e-01        False
# 4         sensitive_topics      125       40  7.469916e-01        False
# 1          rare_procedures        2        1  1.000000e+00        False
#
#            Test  Odds_Ratio Enriched_in
# 6    Chi-square    2.205612          FP
# 2    Chi-square    1.873384          FP
# 0    Chi-square    1.339630           Z
# 5    Chi-square    1.372225           Z
# 3  Fisher Exact    0.454376           Z
# 4    Chi-square    1.087185           Z
# 1  Fisher Exact    0.685237           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: GPT-4o-mini_English | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         307  191
# rare_procedures_present           11    3
# numbers_and_labs_present         231  110
# negation_or_reassurance_present   96   20
# sensitive_topics_present          55   40
# polite_phrases_present            91   64
# narrative_style_present          156   68
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with       p_value  Significant  \
# 3  negation_or_reassurance       96       20  2.652666e-07         True
# 2         numbers_and_labs      231      110  7.360460e-04         True
# 6          narrative_style      156       68  1.650551e-03         True
# 1          rare_procedures       11        3  2.699582e-01        False
# 0         medical_keywords      307      191  4.574826e-01        False
# 4         sensitive_topics       55       40  6.752039e-01        False
# 5           polite_phrases       91       64  7.003211e-01        False
#
#            Test  Odds_Ratio Enriched_in
# 3    Chi-square    3.570248          FP
# 2    Chi-square    1.624642          FP
# 6    Chi-square    1.688124          FP
# 1  Fisher Exact    2.429408           Z
# 0    Chi-square    1.112767           Z
# 4    Chi-square    0.890476           Z
# 5    Chi-square    0.918839           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: GPT-4o-mini_English | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         201  112
# rare_procedures_present            1    3
# numbers_and_labs_present         221  105
# negation_or_reassurance_present    3    3
# sensitive_topics_present          95   56
# polite_phrases_present           117   72
# narrative_style_present          290  127
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with       p_value  Significant  \
# 6          narrative_style      290      127  5.692905e-07         True
# 2         numbers_and_labs      221      105  1.034990e-03         True
# 0         medical_keywords      201      112  1.086176e-01        False
# 1          rare_procedures        1        3  3.066430e-01        False
# 4         sensitive_topics       95       56  5.532341e-01        False
# 3  negation_or_reassurance        3        3  6.860245e-01        False
# 5           polite_phrases      117       72  7.011138e-01        False
#
#            Test  Odds_Ratio Enriched_in
# 6    Chi-square    1.992126          FP
# 2    Chi-square    1.612283          FP
# 0    Chi-square    1.269035           Z
# 1  Fisher Exact    0.217041           Z
# 4    Chi-square    1.133284           Z
# 3  Fisher Exact    0.653380           Z
# 5    Chi-square    1.080994           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-Arabic_Arabic | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         202  137
# rare_procedures_present            7    9
# numbers_and_labs_present         131  103
# negation_or_reassurance_present   19   30
# sensitive_topics_present          28   31
# polite_phrases_present            65   46
# narrative_style_present           82   54
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance       19       30  0.003623         True
# 4         sensitive_topics       28       31  0.068405        False
# 2         numbers_and_labs      131      103  0.208856        False
# 1          rare_procedures        7        9  0.301460        False
# 6          narrative_style       82       54  0.887728        False
# 5           polite_phrases       65       46  0.926462        False
# 0         medical_keywords      202      137  0.982512        False
#
#          Test  Odds_Ratio Enriched_in
# 3  Chi-square    0.402708          FN
# 4  Chi-square    0.586578           Z
# 2  Chi-square    0.799445           Z
# 1  Chi-square    0.522734           Z
# 6  Chi-square    1.048501           Z
# 5  Chi-square    0.958689           Z
# 0  Chi-square    1.016864           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-Arabic_Arabic | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         140   89
# rare_procedures_present            1    7
# numbers_and_labs_present         128   97
# negation_or_reassurance_present    2    4
# sensitive_topics_present          46   46
# polite_phrases_present            81   52
# narrative_style_present          178  123
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 1          rare_procedures        1        7  0.009011         True
# 4         sensitive_topics       46       46  0.061337        False
# 3  negation_or_reassurance        2        4  0.229724        False
# 2         numbers_and_labs      128       97  0.383915        False
# 0         medical_keywords      140       89  0.558366        False
# 5           polite_phrases       81       52  0.765938        False
# 6          narrative_style      178      123  0.962120        False
#
#            Test  Odds_Ratio Enriched_in
# 1  Fisher Exact    0.095238          FN
# 4    Chi-square    0.639394           Z
# 3  Fisher Exact    0.338235           Z
# 2    Chi-square    0.851347           Z
# 0    Chi-square    1.119787           Z
# 5    Chi-square    1.082464           Z
# 6    Chi-square    0.979387           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-Arabic_English | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         281  85
# rare_procedures_present            7   9
# numbers_and_labs_present         196  75
# negation_or_reassurance_present   50  22
# sensitive_topics_present          39  32
# polite_phrases_present            85  31
# narrative_style_present          131  32
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 4         sensitive_topics       39       32  0.000016         True
# 1          rare_procedures        7        9  0.005178         True
# 2         numbers_and_labs      196       75  0.063894        False
# 6          narrative_style      131       32  0.194825        False
# 3  negation_or_reassurance       50       22  0.196876        False
# 5           polite_phrases       85       31  0.477729        False
# 0         medical_keywords      281       85  0.811718        False
#
#          Test  Odds_Ratio Enriched_in
# 4  Chi-square    0.330838          FN
# 1  Chi-square    0.232020          FN
# 2  Chi-square    0.706512           Z
# 6  Chi-square    1.361247           Z
# 3  Chi-square    0.677180           Z
# 5  Chi-square    0.825594           Z
# 0  Chi-square    1.059414           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-Arabic_English | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         207  46
# rare_procedures_present            0   5
# numbers_and_labs_present         189  73
# negation_or_reassurance_present    2   2
# sensitive_topics_present          69  32
# polite_phrases_present           111  35
# narrative_style_present          260  58
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 1          rare_procedures        0        5  0.000719         True
# 6          narrative_style      260       58  0.002598         True
# 0         medical_keywords      207       46  0.012599         True
# 4         sensitive_topics       69       32  0.057027        False
# 2         numbers_and_labs      189       73  0.058735        False
# 3  negation_or_reassurance        2        2  0.240121        False
# 5           polite_phrases      111       35  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 1  Fisher Exact    0.000000          FN
# 6    Chi-square    1.761084          FP
# 0    Chi-square    1.648649          FP
# 4    Chi-square    0.622611           Z
# 2    Chi-square    0.700738           Z
# 3  Fisher Exact    0.308550           Z
# 5    Chi-square    0.983217           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-English_Arabic | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         294  103
# rare_procedures_present           10   10
# numbers_and_labs_present         182   92
# negation_or_reassurance_present   48   28
# sensitive_topics_present          47   30
# polite_phrases_present            91   29
# narrative_style_present          132   42
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 2         numbers_and_labs      182       92  0.000027         True
# 4         sensitive_topics       47       30  0.003380         True
# 3  negation_or_reassurance       48       28  0.014053         True
# 1          rare_procedures       10       10  0.016366         True
# 0         medical_keywords      294      103  0.439751        False
# 6          narrative_style      132       42  0.932395        False
# 5           polite_phrases       91       29  0.981185        False
#
#          Test  Odds_Ratio Enriched_in
# 2  Chi-square    0.481753          FN
# 4  Chi-square    0.469098          FN
# 3  Chi-square    0.520879          FN
# 1  Chi-square    0.315412          FN
# 0  Chi-square    0.864645           Z
# 6  Chi-square    1.038008           Z
# 5  Chi-square    1.032820           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-English_Arabic | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         205  53
# rare_procedures_present            2   6
# numbers_and_labs_present         176  91
# negation_or_reassurance_present    2   3
# sensitive_topics_present          69  40
# polite_phrases_present           114  39
# narrative_style_present          267  77
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 2         numbers_and_labs      176       91  0.000014         True
# 4         sensitive_topics       69       40  0.002448         True
# 1          rare_procedures        2        6  0.003742         True
# 0         medical_keywords      205       53  0.070859        False
# 3  negation_or_reassurance        2        3  0.099351        False
# 6          narrative_style      267       77  0.211943        False
# 5           polite_phrases      114       39  0.873608        False
#
#            Test  Odds_Ratio Enriched_in
# 2    Chi-square    0.468715          FN
# 4    Chi-square    0.504709          FN
# 1  Fisher Exact    0.106007          FN
# 0    Chi-square    1.417173           Z
# 3  Fisher Exact    0.215548           Z
# 6    Chi-square    1.255685           Z
# 5    Chi-square    0.946459           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-English_English | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         194  130
# rare_procedures_present            5    9
# numbers_and_labs_present         136  108
# negation_or_reassurance_present   27   34
# sensitive_topics_present          28   38
# polite_phrases_present            60   45
# narrative_style_present           87   58
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 4         sensitive_topics       28       38  0.003697         True
# 3  negation_or_reassurance       27       34  0.013918         True
# 1          rare_procedures        5        9  0.114424        False
# 2         numbers_and_labs      136      108  0.119582        False
# 5           polite_phrases       60       45  0.626528        False
# 0         medical_keywords      194      130  1.000000        False
# 6          narrative_style       87       58  1.000000        False
#
#          Test  Odds_Ratio Enriched_in
# 4  Chi-square    0.455108          FN
# 3  Chi-square    0.498361          FN
# 1  Chi-square    0.365779           Z
# 2  Chi-square    0.759898           Z
# 5  Chi-square    0.878788           Z
# 0  Chi-square    1.012025           Z
# 6  Chi-square    1.014235           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-English_English | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         138   82
# rare_procedures_present            0    6
# numbers_and_labs_present         130  103
# negation_or_reassurance_present    2    4
# sensitive_topics_present          53   45
# polite_phrases_present            80   52
# narrative_style_present          175  113
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 1          rare_procedures        0        6  0.004106         True
# 2         numbers_and_labs      130      103  0.140750        False
# 3  negation_or_reassurance        2        4  0.226396        False
# 4         sensitive_topics       53       45  0.257090        False
# 0         medical_keywords      138       82  0.297873        False
# 6          narrative_style      175      113  0.686877        False
# 5           polite_phrases       80       52  0.897584        False
#
#            Test  Odds_Ratio Enriched_in
# 1  Fisher Exact    0.000000          FN
# 2    Chi-square    0.768948           Z
# 3  Fisher Exact    0.333333           Z
# 4    Chi-square    0.759012           Z
# 0    Chi-square    1.214634           Z
# 6    Chi-square    1.083268           Z
# 5    Chi-square    1.047009           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-Multilingual_Arabic | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         108  82
# rare_procedures_present            3   7
# numbers_and_labs_present          73  65
# negation_or_reassurance_present    4  17
# sensitive_topics_present          17  26
# polite_phrases_present            38  25
# narrative_style_present           48  25
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance        4       17  0.000166         True
# 4         sensitive_topics       17       26  0.010022         True
# 2         numbers_and_labs       73       65  0.088585        False
# 1          rare_procedures        3        7  0.098961        False
# 6          narrative_style       48       25  0.217833        False
# 0         medical_keywords      108       82  0.483890        False
# 5           polite_phrases       38       25  0.893221        False
#
#            Test  Odds_Ratio Enriched_in
# 3  Fisher Exact    0.148104          FN
# 4    Chi-square    0.408654          FN
# 2    Chi-square    0.666827           Z
# 1  Fisher Exact    0.290043           Z
# 6    Chi-square    1.455686           Z
# 0    Chi-square    0.835563           Z
# 5    Chi-square    1.081718           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-Multilingual_Arabic | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                  FP  FN
# medical_keywords_present         86  43
# rare_procedures_present           1   4
# numbers_and_labs_present         71  63
# negation_or_reassurance_present   0   2
# sensitive_topics_present         24  31
# polite_phrases_present           52  28
# narrative_style_present          96  64
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 4         sensitive_topics       24       31  0.019297         True
# 0         medical_keywords       86       43  0.028172         True
# 2         numbers_and_labs       71       63  0.102578        False
# 1          rare_procedures        1        4  0.163858        False
# 3  negation_or_reassurance        0        2  0.169265        False
# 5           polite_phrases       52       28  0.244751        False
# 6          narrative_style       96       64  0.747064        False
#
#            Test  Odds_Ratio Enriched_in
# 4    Chi-square    0.481137          FN
# 0    Chi-square    1.704348          FP
# 2    Chi-square    0.676190           Z
# 1  Fisher Exact    0.171250           Z
# 3  Fisher Exact    0.000000           Z
# 5    Chi-square    1.408437           Z
# 6    Chi-square    1.100000           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-Multilingual_English | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         107  73
# rare_procedures_present            3   6
# numbers_and_labs_present          68  61
# negation_or_reassurance_present    8  18
# sensitive_topics_present          19  20
# polite_phrases_present            34  21
# narrative_style_present           39  29
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance        8       18  0.005763         True
# 2         numbers_and_labs       68       61  0.124582        False
# 1          rare_procedures        3        6  0.171652        False
# 4         sensitive_topics       19       20  0.261536        False
# 5           polite_phrases       34       21  0.671791        False
# 0         medical_keywords      107       73  0.739270        False
# 6          narrative_style       39       29  0.963387        False
#
#            Test  Odds_Ratio Enriched_in
# 3    Chi-square    0.288416          FN
# 2    Chi-square    0.688012           Z
# 1  Fisher Exact    0.347150           Z
# 4    Chi-square    0.644068           Z
# 5    Chi-square    1.189300           Z
# 0    Chi-square    1.103432           Z
# 6    Chi-square    0.950802           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: XLM-R-Multilingual_English | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present          87  57
# rare_procedures_present            1   5
# numbers_and_labs_present          65  57
# negation_or_reassurance_present    1   3
# sensitive_topics_present          22  23
# polite_phrases_present            42  23
# narrative_style_present          100  67
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 1          rare_procedures        1        5  0.085826        False
# 2         numbers_and_labs       65       57  0.192254        False
# 4         sensitive_topics       22       23  0.223066        False
# 3  negation_or_reassurance        1        3  0.311871        False
# 5           polite_phrases       42       23  0.315458        False
# 0         medical_keywords       87       57  0.576150        False
# 6          narrative_style      100       67  0.644743        False
#
#            Test  Odds_Ratio Enriched_in
# 1  Fisher Exact    0.138462           Z
# 2    Chi-square    0.722512           Z
# 4    Chi-square    0.643178           Z
# 3  Fisher Exact    0.234188           Z
# 5    Chi-square    1.387352           Z
# 0    Chi-square    1.162240           Z
# 6    Chi-square    1.134950           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_base_concerning_normal_Arabic | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         535  23
# rare_procedures_present           14   1
# numbers_and_labs_present         461  13
# negation_or_reassurance_present  192   2
# sensitive_topics_present         112   1
# polite_phrases_present           179   4
# narrative_style_present          241  12
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance      192        2  0.022115         True
# 4         sensitive_topics      112        1  0.115919        False
# 2         numbers_and_labs      461       13  0.134442        False
# 5           polite_phrases      179        4  0.289951        False
# 1          rare_procedures       14        1  0.446579        False
# 6          narrative_style      241       12  0.507081        False
# 0         medical_keywords      535       23  0.739081        False
#
#            Test  Odds_Ratio Enriched_in
# 3  Fisher Exact    4.470314          FP
# 4  Fisher Exact    4.890309           Z
# 2    Chi-square    1.743025           Z
# 5  Fisher Exact    1.950115           Z
# 1  Fisher Exact    0.553520           Z
# 6    Chi-square    0.743827           Z
# 0    Chi-square    0.856505           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_base_concerning_normal_Arabic | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         278  15
# rare_procedures_present            4   0
# numbers_and_labs_present         445  12
# negation_or_reassurance_present    6   0
# sensitive_topics_present         197   1
# polite_phrases_present           229   8
# narrative_style_present          433  19
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 4         sensitive_topics      197        1  0.003509         True
# 2         numbers_and_labs      445       12  0.106417        False
# 0         medical_keywords      278       15  0.249580        False
# 6          narrative_style      433       19  0.717743        False
# 5           polite_phrases      229        8  0.816693        False
# 1          rare_procedures        4        0  1.000000        False
# 3  negation_or_reassurance        6        0  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 4  Fisher Exact    9.457845          FP
# 2    Chi-square    1.835809           Z
# 0    Chi-square    0.647348           Z
# 6    Chi-square    0.848152           Z
# 5    Chi-square    1.184002           Z
# 1  Fisher Exact         inf           Z
# 3  Fisher Exact         inf           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_base_concerning_normal_English | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         343  205
# rare_procedures_present            5    7
# numbers_and_labs_present         283  138
# negation_or_reassurance_present  111   27
# sensitive_topics_present          76   19
# polite_phrases_present            96   82
# narrative_style_present          162   72
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance      111       27  0.000132         True
# 5           polite_phrases       96       82  0.000439         True
# 4         sensitive_topics       76       19  0.002947         True
# 0         medical_keywords      343      205  0.037079         True
# 1          rare_procedures        5        7  0.146199        False
# 6          narrative_style      162       72  0.219027        False
# 2         numbers_and_labs      283      138  0.418631        False
#
#          Test  Odds_Ratio Enriched_in
# 3  Chi-square    2.367003          FP
# 5  Chi-square    0.551724          FN
# 4  Chi-square    2.225755          FP
# 0  Chi-square    0.758011          FN
# 1  Chi-square    0.369388           Z
# 6  Chi-square    1.230663           Z
# 2  Chi-square    1.122553           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_base_concerning_normal_English | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         177  164
# rare_procedures_present            2    4
# numbers_and_labs_present         275  132
# negation_or_reassurance_present    2    0
# sensitive_topics_present         123   43
# polite_phrases_present           133  103
# narrative_style_present          278  161
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with       p_value  Significant  \
# 0         medical_keywords      177      164  1.591251e-10         True
# 5           polite_phrases      133      103  8.897491e-04         True
# 4         sensitive_topics      123       43  1.614861e-02         True
# 1          rare_procedures        2        4  1.893551e-01        False
# 6          narrative_style      278      161  2.062546e-01        False
# 2         numbers_and_labs      275      132  3.312911e-01        False
# 3  negation_or_reassurance        2        0  5.485169e-01        False
#
#            Test  Odds_Ratio Enriched_in
# 0    Chi-square    0.419034          FN
# 5    Chi-square    0.600482          FN
# 4    Chi-square    1.602254          FP
# 1  Fisher Exact    0.259602           Z
# 6    Chi-square    0.841113           Z
# 2    Chi-square    1.148256           Z
# 3  Fisher Exact         inf           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_base_distressed_stable_Arabic | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         535  16
# rare_procedures_present           15   1
# numbers_and_labs_present         473  11
# negation_or_reassurance_present  194   1
# sensitive_topics_present         111   1
# polite_phrases_present           185   4
# narrative_style_present          243   9
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance      194        1  0.008720         True
# 2         numbers_and_labs      473       11  0.061614        False
# 4         sensitive_topics      111        1  0.171242        False
# 5           polite_phrases      185        4  0.287133        False
# 0         medical_keywords      535       16  0.316598        False
# 1          rare_procedures       15        1  0.441616        False
# 6          narrative_style      243        9  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 3  Fisher Exact    8.522543          FP
# 2    Chi-square    2.054608           Z
# 4  Fisher Exact    4.449367           Z
# 5  Fisher Exact    1.852117           Z
# 0    Chi-square    1.467677           Z
# 1  Fisher Exact    0.545977           Z
# 6    Chi-square    0.992647           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_base_distressed_stable_Arabic | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         279  13
# rare_procedures_present            4   1
# numbers_and_labs_present         457  11
# negation_or_reassurance_present    6   1
# sensitive_topics_present         199   1
# polite_phrases_present           233   8
# narrative_style_present          433  20
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 4         sensitive_topics      199        1  0.005370         True
# 2         numbers_and_labs      457       11  0.091204        False
# 1          rare_procedures        4        1  0.165700        False
# 3  negation_or_reassurance        6        1  0.224203        False
# 6          narrative_style      433       20  0.258751        False
# 0         medical_keywords      279       13  0.432188        False
# 5           polite_phrases      233        8  0.981109        False
#
#            Test  Odds_Ratio Enriched_in
# 4  Fisher Exact    8.793023          FP
# 2    Chi-square    1.932347           Z
# 1  Fisher Exact    0.144076           Z
# 3  Fisher Exact    0.216524           Z
# 6    Chi-square    0.657109           Z
# 0    Chi-square    0.715385           Z
# 5    Chi-square    1.093069           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_base_distressed_stable_English | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         547   1
# rare_procedures_present           15   0
# numbers_and_labs_present         478   0
# negation_or_reassurance_present  196   0
# sensitive_topics_present         112   0
# polite_phrases_present           186   0
# narrative_style_present          250   1
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 6          narrative_style      250        1  0.408993        False
# 2         numbers_and_labs      478        0  0.506710        False
# 0         medical_keywords      547        1  1.000000        False
# 1          rare_procedures       15        0  1.000000        False
# 3  negation_or_reassurance      196        0  1.000000        False
# 4         sensitive_topics      112        0  1.000000        False
# 5           polite_phrases      186        0  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 6  Fisher Exact    0.299760           Z
# 2  Fisher Exact         inf           Z
# 0  Fisher Exact    1.018622           Z
# 1  Fisher Exact         inf           Z
# 3  Fisher Exact         inf           Z
# 4  Fisher Exact         inf           Z
# 5  Fisher Exact         inf           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_base_distressed_stable_English | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         285   1
# rare_procedures_present            4   0
# numbers_and_labs_present         462   0
# negation_or_reassurance_present    6   0
# sensitive_topics_present         199   0
# polite_phrases_present           238   0
# narrative_style_present          444   1
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 0         medical_keywords      285        1  0.457528        False
# 2         numbers_and_labs      462        0  0.510675        False
# 1          rare_procedures        4        0  1.000000        False
# 3  negation_or_reassurance        6        0  1.000000        False
# 4         sensitive_topics      199        0  1.000000        False
# 5           polite_phrases      238        0  1.000000        False
# 6          narrative_style      444        1  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 0  Fisher Exact    0.356696           Z
# 2  Fisher Exact         inf           Z
# 1  Fisher Exact         inf           Z
# 3  Fisher Exact         inf           Z
# 4  Fisher Exact         inf           Z
# 5  Fisher Exact         inf           Z
# 6  Fisher Exact    0.693750           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_base_trigger_non-trigger_Arabic | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         359  190
# rare_procedures_present           11    3
# numbers_and_labs_present         275  114
# negation_or_reassurance_present  114   23
# sensitive_topics_present          69   30
# polite_phrases_present           127   36
# narrative_style_present          156   68
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance      114       23  0.000002         True
# 5           polite_phrases      127       36  0.000196         True
# 2         numbers_and_labs      275      114  0.002697         True
# 6          narrative_style      156       68  0.103264        False
# 4         sensitive_topics       69       30  0.337563        False
# 1          rare_procedures       11        3  0.400622        False
# 0         medical_keywords      359      190  0.728174        False
#
#            Test  Odds_Ratio Enriched_in
# 3    Chi-square    3.033885          FP
# 5    Chi-square    2.126948          FP
# 2    Chi-square    1.521963          FP
# ...
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_trigger_non-trigger_Arabic | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         265  27
# rare_procedures_present            3   1
# numbers_and_labs_present         396  35
# negation_or_reassurance_present    5   0
# sensitive_topics_present         175   9
# polite_phrases_present           210  13
# narrative_style_present          387  42
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 4         sensitive_topics      175        9  0.098391        False
# 6          narrative_style      387       42  0.147368        False
# 5           polite_phrases      210       13  0.188349        False
# 1          rare_procedures        3        1  0.290127        False
# 0         medical_keywords      265       27  0.520165        False
# 2         numbers_and_labs      396       35  1.000000        False
# 3  negation_or_reassurance        5        0  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 4    Chi-square    1.900028           Z
# 6    Chi-square    0.703869           Z
# 5    Chi-square    1.566044           Z
# 1  Fisher Exact    0.265625           Z
# 0    Chi-square    0.829619           Z
# 2    Chi-square    1.017687           Z
# 3  Fisher Exact         inf           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_trigger_non-trigger_English | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         508  36
# rare_procedures_present           15   1
# numbers_and_labs_present         443  32
# negation_or_reassurance_present  182   3
# sensitive_topics_present         103   2
# polite_phrases_present           162  13
# narrative_style_present          228  20
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 3  negation_or_reassurance      182        3  0.001540         True
# 4         sensitive_topics      103        2  0.056040        False
# 6          narrative_style      228       20  0.298666        False
# 5           polite_phrases      162       13  0.679946        False
# 2         numbers_and_labs      443       32  0.822047        False
# 0         medical_keywords      508       36  0.910330        False
# 1          rare_procedures       15        1  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 3  Fisher Exact    4.882927          FP
# 4  Fisher Exact    3.838154           Z
# 6    Chi-square    0.721705           Z
# 5    Chi-square    0.830769           Z
# 2    Chi-square    0.916313           Z
# 0    Chi-square    0.942645           Z
# 1  Fisher Exact    1.033435           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_trigger_non-trigger_English | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         267  34
# rare_procedures_present            3   1
# numbers_and_labs_present         429  32
# negation_or_reassurance_present    5   1
# sensitive_topics_present         185   7
# polite_phrases_present           213  15
# narrative_style_present          400  39
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 0         medical_keywords      267       34  0.000094         True
# 6          narrative_style      400       39  0.009721         True
# 4         sensitive_topics      185        7  0.114082        False
# 1          rare_procedures        3        1  0.234148        False
# 3  negation_or_reassurance        5        1  0.330040        False
# 2         numbers_and_labs      429       32  0.650986        False
# 5           polite_phrases      213       15  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 0    Chi-square    0.373950          FN
# 6    Chi-square    0.511117          FN
# 4    Chi-square    2.005595           Z
# 1  Fisher Exact    0.204204           Z
# 3  Fisher Exact    0.341023           Z
# 2    Chi-square    0.865674           Z
# 5    Chi-square    0.971863           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_urgent_non-urgent_Arabic | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         480  57
# rare_procedures_present           12   0
# numbers_and_labs_present         415  33
# negation_or_reassurance_present  161  13
# sensitive_topics_present          95   5
# polite_phrases_present           168  15
# narrative_style_present          195  34
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 2         numbers_and_labs      415       33  0.000798         True
# 4         sensitive_topics       95        5  0.054822        False
# 6          narrative_style      195       34  0.070194        False
# 3  negation_or_reassurance      161       13  0.108132        False
# 5           polite_phrases      168       15  0.186311        False
# 1          rare_procedures       12        0  0.380480        False
# 0         medical_keywords      480       57  0.549864        False
#
#            Test  Odds_Ratio Enriched_in
# 2    Chi-square    2.075845          FP
# 4    Chi-square    2.575505           Z
# 6    Chi-square    0.657895           Z
# 3    Chi-square    1.693896           Z
# 5    Chi-square    1.516667           Z
# 1  Fisher Exact         inf           Z
# 0    Chi-square    1.144968           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_urgent_non-urgent_Arabic | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP  FN
# medical_keywords_present         245  51
# rare_procedures_present            3   0
# numbers_and_labs_present         402  33
# negation_or_reassurance_present    3   1
# sensitive_topics_present         166   7
# polite_phrases_present           216  15
# narrative_style_present          377  60
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 0         medical_keywords      245       51  0.000210         True
# 4         sensitive_topics      166        7  0.001589         True
# 2         numbers_and_labs      402       33  0.002087         True
# 5           polite_phrases      216       15  0.012983         True
# 6          narrative_style      377       60  0.043710         True
# 3  negation_or_reassurance        3        1  0.380874        False
# 1          rare_procedures        3        0  1.000000        False
#
#            Test  Odds_Ratio Enriched_in
# 0    Chi-square    0.472745          FN
# 4    Chi-square    3.449351          FP
# 2    Chi-square    1.961866          FP
# 5    Chi-square    2.080000          FP
# 6    Chi-square    0.663178          FN
# 3  Fisher Exact    0.379421           Z
# 1  Fisher Exact         inf           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_urgent_non-urgent_English | on col LANGUAGE: ar
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         440  111
# rare_procedures_present           15    2
# numbers_and_labs_present         369   66
# negation_or_reassurance_present  139   22
# sensitive_topics_present          88   12
# polite_phrases_present           123   32
# narrative_style_present          173   47
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with   p_value  Significant  \
# 2         numbers_and_labs      369       66  0.008337         True
# 3  negation_or_reassurance      139       22  0.073154        False
# 4         sensitive_topics       88       12  0.078329        False
# 6          narrative_style      173       47  0.380725        False
# 0         medical_keywords      440      111  0.393003        False
# 5           polite_phrases      123       32  0.668232        False
# 1          rare_procedures       15        2  0.754329        False
#
#            Test  Odds_Ratio Enriched_in
# 2    Chi-square    1.566879          FP
# 3    Chi-square    1.586305           Z
# 4    Chi-square    1.813830           Z
# 6    Chi-square    0.833296           Z
# 0    Chi-square    0.862162           Z
# 5    Chi-square    0.889906           Z
# 1  Fisher Exact    1.781818           Z
# ================================================================================
#
#
# ================================================================================
# MODEL / CSV: ZeroShot_urgent_non-urgent_English | on col LANGUAGE: en
# --------------------------------------------------------------------------------
# FP / FN Counts:
#                                   FP   FN
# medical_keywords_present         222   91
# rare_procedures_present            4    2
# numbers_and_labs_present         358   66
# negation_or_reassurance_present    4    2
# sensitive_topics_present         159   13
# polite_phrases_present           174   33
# narrative_style_present          314  112
# --------------------------------------------------------------------------------
# Significance Table:
#                    Keyword  FP_with  FN_with       p_value  Significant  \
# 0         medical_keywords      222       91  1.151534e-07         True
# 6          narrative_style      314      112  1.194787e-06         True
# 4         sensitive_topics      159       13  4.084194e-05         True
# 2         numbers_and_labs      358       66  2.084058e-02         True
# 5           polite_phrases      174       33  2.366393e-01        False
# 1          rare_procedures        4        2  3.218655e-01        False
# 3  negation_or_reassurance        4        2  3.218655e-01        False
#
#            Test  Odds_Ratio Enriched_in
# 0    Chi-square    0.422383          FN
# 6    Chi-square    0.458379          FN
# 4    Chi-square    3.322603          FP
# 2    Chi-square    1.485477          FP
# 5    Chi-square    1.306306           Z
# 1  Fisher Exact    0.468900           Z
# 3  Fisher Exact    0.468900           Z
# ================================================================================
#
#
# SUMMARY OF SIGNIFICANT FEATURES PER MODEL / LANGUAGE:
#   Claude-Haiku-4.5_Arabic_ar Claude-Haiku-4.5_Arabic_en  \
# 0    negation_or_reassurance           numbers_and_labs
# 1           numbers_and_labs            narrative_style
# 2            narrative_style                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#   Claude-Haiku-4.5_English_ar Claude-Haiku-4.5_English_en  \
# 0     negation_or_reassurance            numbers_and_labs
# 1            numbers_and_labs             narrative_style
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#      GPT-4o-mini_Arabic_ar GPT-4o-mini_Arabic_en   GPT-4o-mini_English_ar  \
# 0  negation_or_reassurance       narrative_style  negation_or_reassurance
# 1         numbers_and_labs      numbers_and_labs         numbers_and_labs
# 2          narrative_style                   NaN          narrative_style
# 3                      NaN                   NaN                      NaN
# 4                      NaN                   NaN                      NaN
#
#   GPT-4o-mini_English_en   XLM-R-Arabic_Arabic_ar XLM-R-Arabic_Arabic_en  ...  \
# 0        narrative_style  negation_or_reassurance        rare_procedures  ...
# 1       numbers_and_labs                      NaN                    NaN  ...
# 2                    NaN                      NaN                    NaN  ...
# 3                    NaN                      NaN                    NaN  ...
# 4                    NaN                      NaN                    NaN  ...
#
#   ZeroShot_distressed_stable_English_ar ZeroShot_distressed_stable_English_en  \
# 0                      numbers_and_labs                        polite_phrases
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#   ZeroShot_trigger_non-trigger_Arabic_ar  \
# 0                negation_or_reassurance
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ZeroShot_trigger_non-trigger_Arabic_en  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ZeroShot_trigger_non-trigger_English_ar  \
# 0                 negation_or_reassurance
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   ZeroShot_trigger_non-trigger_English_en  \
# 0                        medical_keywords
# 1                         narrative_style
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   ZeroShot_urgent_non-urgent_Arabic_ar ZeroShot_urgent_non-urgent_Arabic_en  \
# 0                     numbers_and_labs                     medical_keywords
# 1                                  NaN                     sensitive_topics
# 2                                  NaN                     numbers_and_labs
# 3                                  NaN                       polite_phrases
# 4                                  NaN                      narrative_style
#
#   ZeroShot_urgent_non-urgent_English_ar ZeroShot_urgent_non-urgent_English_en
# 0                      numbers_and_labs                      medical_keywords
# 1                                   NaN                       narrative_style
# 2                                   NaN                      sensitive_topics
# 3                                   NaN                      numbers_and_labs
# 4                                   NaN                                   NaN
#
# [5 rows x 52 columns]

# %%
import pandas as pd
from tabulate import tabulate  # pip install tabulate

# all_sig = dictionary of model/language -> list of significant features

# 1️⃣ Find the maximum number of features across all models
max_len = max(len(v) for v in all_sig.values())

# 2️⃣ Pad each list with empty strings to make them equal length
padded_features = {k: v + [""]*(max_len - len(v)) for k, v in all_sig.items()}

# 3️⃣ Create a DataFrame
summary_df = pd.DataFrame(padded_features)

# 4️⃣ Transpose: models/languages as rows
summary_df = summary_df.T.reset_index()
summary_df.rename(columns={'index': 'Model / Language'}, inplace=True)

# 5️⃣ Rename feature columns
summary_df.columns = ['Model / Language'] + [f'Feature_{i+1}' for i in range(max_len)]

# 6️⃣ Convert to pretty table string using tabulate
table_str = tabulate(summary_df, headers='keys', tablefmt='grid', showindex=False)

# 7️⃣ Print table
print("="*120)
print("SUMMARY OF SIGNIFICANT FEATURES PER MODEL / LANGUAGE (TRANSPOSED)")
print("="*120)
print(table_str)

# 8️⃣ Save to a new text file
txt_path = "summary_significant_features.txt"
with open(txt_path, "w", encoding="utf-8") as f:
    f.write("="*120 + "\n")
    f.write("SUMMARY OF SIGNIFICANT FEATURES PER MODEL / LANGUAGE (TRANSPOSED)\n")
    f.write("="*120 + "\n")
    f.write(table_str)

print(f"\n✅ Transposed summary saved to: {txt_path}")
# Out:
# ========================================================================================================================
# SUMMARY OF SIGNIFICANT FEATURES PER MODEL / LANGUAGE (TRANSPOSED)
# ========================================================================================================================
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | Model / Language                             | Feature_1               | Feature_2               | Feature_3               | Feature_4        | Feature_5        |
# +==============================================+=========================+=========================+=========================+==================+==================+
# | Claude-Haiku-4.5_Arabic_ar                   | negation_or_reassurance | numbers_and_labs        | narrative_style         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | Claude-Haiku-4.5_Arabic_en                   | numbers_and_labs        | narrative_style         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | Claude-Haiku-4.5_English_ar                  | negation_or_reassurance | numbers_and_labs        |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | Claude-Haiku-4.5_English_en                  | numbers_and_labs        | narrative_style         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | GPT-4o-mini_Arabic_ar                        | negation_or_reassurance | numbers_and_labs        | narrative_style         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | GPT-4o-mini_Arabic_en                        | narrative_style         | numbers_and_labs        |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | GPT-4o-mini_English_ar                       | negation_or_reassurance | numbers_and_labs        | narrative_style         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | GPT-4o-mini_English_en                       | narrative_style         | numbers_and_labs        |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-Arabic_Arabic_ar                       | negation_or_reassurance |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-Arabic_Arabic_en                       | rare_procedures         |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-Arabic_English_ar                      | sensitive_topics        | rare_procedures         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-Arabic_English_en                      | rare_procedures         | narrative_style         | medical_keywords        |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-English_Arabic_ar                      | numbers_and_labs        | sensitive_topics        | negation_or_reassurance | rare_procedures  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-English_Arabic_en                      | numbers_and_labs        | sensitive_topics        | rare_procedures         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-English_English_ar                     | sensitive_topics        | negation_or_reassurance |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-English_English_en                     | rare_procedures         |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-Multilingual_Arabic_ar                 | negation_or_reassurance | sensitive_topics        |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-Multilingual_Arabic_en                 | sensitive_topics        | medical_keywords        |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-Multilingual_English_ar                | negation_or_reassurance |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | XLM-R-Multilingual_English_en                |                         |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_concerning_normal_Arabic_ar    | negation_or_reassurance |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_concerning_normal_Arabic_en    | sensitive_topics        |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_concerning_normal_English_ar   | negation_or_reassurance | polite_phrases          | sensitive_topics        | medical_keywords |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_concerning_normal_English_en   | medical_keywords        | polite_phrases          | sensitive_topics        |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_distressed_stable_Arabic_ar    | negation_or_reassurance |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_distressed_stable_Arabic_en    | sensitive_topics        |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_distressed_stable_English_ar   |                         |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_distressed_stable_English_en   |                         |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_trigger_non-trigger_Arabic_ar  | negation_or_reassurance | polite_phrases          | numbers_and_labs        |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_trigger_non-trigger_Arabic_en  | polite_phrases          | sensitive_topics        | medical_keywords        | narrative_style  | numbers_and_labs |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_trigger_non-trigger_English_ar | medical_keywords        | narrative_style         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_trigger_non-trigger_English_en | medical_keywords        |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_urgent_non-urgent_Arabic_ar    | negation_or_reassurance | sensitive_topics        |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_urgent_non-urgent_Arabic_en    | medical_keywords        | sensitive_topics        |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_urgent_non-urgent_English_ar   | negation_or_reassurance | polite_phrases          |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_base_urgent_non-urgent_English_en   | polite_phrases          | narrative_style         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_concerning_normal_Arabic_ar         | polite_phrases          | negation_or_reassurance | rare_procedures         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_concerning_normal_Arabic_en         | sensitive_topics        | polite_phrases          | medical_keywords        | rare_procedures  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_concerning_normal_English_ar        |                         |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_concerning_normal_English_en        | rare_procedures         | sensitive_topics        | medical_keywords        |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_distressed_stable_Arabic_ar         | narrative_style         | polite_phrases          |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_distressed_stable_Arabic_en         | polite_phrases          | sensitive_topics        |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_distressed_stable_English_ar        | numbers_and_labs        |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_distressed_stable_English_en        | polite_phrases          |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_trigger_non-trigger_Arabic_ar       | negation_or_reassurance |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_trigger_non-trigger_Arabic_en       |                         |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_trigger_non-trigger_English_ar      | negation_or_reassurance |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_trigger_non-trigger_English_en      | medical_keywords        | narrative_style         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_urgent_non-urgent_Arabic_ar         | numbers_and_labs        |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_urgent_non-urgent_Arabic_en         | medical_keywords        | sensitive_topics        | numbers_and_labs        | polite_phrases   | narrative_style  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_urgent_non-urgent_English_ar        | numbers_and_labs        |                         |                         |                  |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
# | ZeroShot_urgent_non-urgent_English_en        | medical_keywords        | narrative_style         | sensitive_topics        | numbers_and_labs |                  |
# +----------------------------------------------+-------------------------+-------------------------+-------------------------+------------------+------------------+
#
# ✅ Transposed summary saved to: summary_significant_features.txt
